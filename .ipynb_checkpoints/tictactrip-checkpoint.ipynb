# %% [markdown]
# # Steps
#    ### Read the csv files
#        1. write a script that check if we have out csv files in the working diretory
#        2. write the script to load them
#        3. save this script as a module (utils.py)
#        4. import the util module and use it to load the csv files as dataframes
#    ### Data cleaning
#        1. check for NaN values replace them or delete them, depending on the impact they shall have on our results
#        2. Data type verifiacation, each columb should have the same data type
#        3. we may add relevant and neccessay columbs(calculated or derives frome other columns)
#        4. analyse and choice the column(s) that shall be used to relate and combine our dataframes
#        5. combine our dataframes to form one clean and organised dataframe
#
#   ### Get insides from the dataframe
#        1. min, max and mean prices
#        2. min, max and mean duration per trip
#        3. average price difference and duration depending on the train, the bus and the carpool depending on the distance of the journey (0-200km, 201-800km, 800-2000km, 2000 + km)
#
#   ### Graph and Plots
#       1. all the cities with stations
#
#  ### Get some predictions

# %% [markdown]
# - ticket_data.csv: Containing a ticket history (one line => a ticket proposal on tictactrip)
#
#  - cities.csv the cities served by tictactrip (link thanks to the o_city (origin_city), d_city (destination_city) columns of ticket_data)
#
#  - stations.csv stations served by tictactrip (link via o_station, d_station from ticket_data)
#
#  - providers.csv info on the different providers (link via company from ticket_data)
# A provider is a "sub-company". For example TGV and TER are two providers of VSC (voyages-sncf).

# %% [markdown]
# ### Read the csv files

# %%
#imports
import pandas as pd
import numpy as np
import utils as ut

# %%
# we check if we have all the required files in the current directory
ut.list_file_with_extension_cur_glob ('csv')

# %%
#lets load our csv files as dateframe

cities = ut.read_dataset('cities.csv')
providers = ut.read_dataset('providers.csv')
stations = ut.read_dataset('stations.csv')
ticket_data = ut.read_dataset('ticket_data.csv')

# %% [markdown]
# ### Data cleaning

# %% [markdown]
# #### Cleaning ticket_data dataframe
#     1. create dataframe that conatins a NaN value in any colomns and or rows in the dataframe
#     2. Decid how to solve it, either by deleting them or by replacing them

# %% [markdown]
# ##### replacing NaN for middle_stations and	other_companies columns with an empty list 0,
#     for middle_stations: it indicates no middle station for that trip
#     other_companies: it indicates no other company does that trip

# %%
# def replace_nan_for_middle_stations_and_other_companies_with_zero(ticket_data):
ut.replace_nan_for_middle_stations_and_other_companies_with_zero(ticket_data)

# %%
#changing the dates data type from string to datetime(to permit use to get the jouney duration easily)
ut.change_date_data_type_from_string_to_datetime(ticket_data)

# %%
#adding trip duration in hours using the departure_ts and the arrival_ts colombs
ut.add_trip_duration_column_to_ticket_data(ticket_data)

# %% [markdown]
# #### NaN

# %%
# import requests
# import json

# def get_city_opendata(city, country):
#     tmp = 'https://public.opendatasoft.com/api/records/1.0/search/?dataset=worldcitiespop&q=%s&sort=population&facet=country&refine.country=%s'
#     cmd = tmp % (city, country)
#     res = requests.get(cmd)
#     dct = json.loads(res.content)
#     out = dct['records'][0]['fields']
#     return out

# get_city_opendata('Berlin', 'de')

cities.tail()
cities[cities.isna().any(axis=1)]
# population colomns contains some NaN, so we may solve this with a population API
# Out:
#          id                                      local_name  \
# 2        81                     Basel, Basel-Stadt, Schweiz
# 4     11979                              Balș, Olt, România
# 5     10314        Град Пожаревац, Централна Србија, Србија
# 6     11155                Bussy-Lettrée, Grand-Est, France
# 7     11788                 Chamonix, Valle d'Aosta, Italia
# ...     ...                                             ...
# 8035   9964  Saint-André-lez-Lille, Hauts-de-France, France
# 8036  10863             Kiev, Шевченківський район, Ukraine
# 8037  11144                           Brighton, England, UK
# 8038  11377           Manises, Comunitat Valenciana, España
# 8039  11537               South Cambridgeshire, England, UK
#
#                 unique_name   latitude  longitude  population
# 2                     basel  47.593437   7.619812         NaN
# 4                      balș  44.353354  24.095672         NaN
# ...

# %%
providers.tail(10)
# providers[providers.isna().any(axis=1)] #provider id is nan for some rows
# Out:
#        id  company_id provider_id         name            fullname has_wifi  \
# 217  8379          10           4      navette      Navette Keolis    False
# 218  8380          10           5        train                 TER    False
# 219  8381          10           6  coraillunea  Intercités de Nuit    False
# 220  8382          10           8     eurostar            Eurostar    False
# 221  8383          10           9       corail          Intercités    False
# 222  8384          10          16       thalys              Thalys     True
# 223  8385          11         NaN          bbc           Blablacar    False
# 224  8387          30         NaN        vatry               Vatry      NaN
# 225  8388          40         NaN      beauval             Beauval      NaN
# 226  8389          12         NaN      idvroom             idVroom    False
#
#     has_plug has_adjustable_seats has_bicycle transport_type
# 217    False                 True       False            bus
# ...

# %%
stations.tail()
# stations[stations.isna().any(axis=1)] #check for null values in the stations dataframe
# has no nan
# Out:
#           id                                        unique_name   latitude  \
# 11030  11032                          Porto Avda De Los Aliados  41.146922
# 11031  11033  Rom Ciampino Flughafen Piazzale Leonardo da Vinci  41.804102
# 11032  11034                                              Sants  41.379892
# 11033  11035                                       Vozilici D66  45.157136
# 11034  11036                     Wien Hotel ibis Vienna Airport  48.123229
#
#        longitude
# 11030  -8.611122
# 11031  12.597110
# 11032   2.139462
# 11033  14.164140
# 11034  16.437528

# %%
s = ut.join_city_to_ticket_data(cities, ticket_data)
s






# station_unique_name = stations.set_index('id')['latitude']
# station_unique_name
# s.where(s['o_city_longitude']==stations['longitude']).notna()
# stations.dtypes
# comparison_column = np.where(s["o_city_longitude"] == stations['longitude'] ,  True, False)
# ticket_data['o_city_latitude'].map(station_unique_name).head(60)
# Out:
#             id  company  o_station  d_station              departure_ts  \
# 0      6795025     8385        NaN        NaN 2017-10-13 14:00:00+00:00
# 1      6795026        9       63.0     1044.0 2017-10-13 13:05:00+00:00
# 2      6795027     8377     5905.0     6495.0 2017-10-13 13:27:00+00:00
# 3      6795028     8377     5905.0     6495.0 2017-10-13 13:27:00+00:00
# 4      6795029     8381     5905.0     6495.0 2017-10-13 21:46:00+00:00
# ...        ...      ...        ...        ...                       ...
# 74163  6869182       13      279.0    10729.0 2017-10-27 02:30:00+00:00
# 74164  6869185        9      279.0      304.0 2017-10-27 07:00:00+00:00
# 74165  6869187     8371    10642.0      304.0 2017-10-27 08:30:00+00:00
# 74166  6869189       13      279.0      304.0 2017-10-27 13:25:00+00:00
# 74167  6869191     8371    10642.0    10729.0 2017-10-27 14:45:00+00:00
#
#                      arrival_ts  price_in_cents  \
# 0     2017-10-13 20:10:00+00:00            4550
# ...

# %%
# ticket_data
# ticket_data[ticket_data.isna().any(axis=1)]

# %%
 pd.merge(left=ticket_data, right=providers, left_on='company', right_on='company_id')
# Out:
#            id_x  company  o_station  d_station              departure_ts  \
# 0       6795026        9       63.0     1044.0 2017-10-13 13:05:00+00:00
# 1       6795026        9       63.0     1044.0 2017-10-13 13:05:00+00:00
# 2       6795026        9       63.0     1044.0 2017-10-13 13:05:00+00:00
# 3       6795026        9       63.0     1044.0 2017-10-13 13:05:00+00:00
# 4       6795026        9       63.0     1044.0 2017-10-13 13:05:00+00:00
# ...         ...      ...        ...        ...                       ...
# 715659  6848395       12      283.0     1595.0 2017-10-27 06:00:00+00:00
# 715660  6848396       12      283.0     1593.0 2017-10-27 06:00:00+00:00
# 715661  6852979       12      523.0       86.0 2017-10-30 21:30:00+00:00
# 715662  6853589       12      283.0      523.0 2017-12-22 18:30:00+00:00
# 715663  6856599       12      283.0      523.0 2017-11-03 18:30:00+00:00
#
#                       arrival_ts  price_in_cents  \
# ...

# %%
#This function merges the cities data and the tiket_data dataframes in a consistent way
ut.join_city_to_ticket_data(cities, ticket_data)
# Out:
#             id  company  o_station  d_station              departure_ts  \
# 0      6795025     8385        NaN        NaN 2017-10-13 14:00:00+00:00
# 1      6795026        9       63.0     1044.0 2017-10-13 13:05:00+00:00
# 2      6795027     8377     5905.0     6495.0 2017-10-13 13:27:00+00:00
# 3      6795028     8377     5905.0     6495.0 2017-10-13 13:27:00+00:00
# 4      6795029     8381     5905.0     6495.0 2017-10-13 21:46:00+00:00
# ...        ...      ...        ...        ...                       ...
# 74163  6869182       13      279.0    10729.0 2017-10-27 02:30:00+00:00
# 74164  6869185        9      279.0      304.0 2017-10-27 07:00:00+00:00
# 74165  6869187     8371    10642.0      304.0 2017-10-27 08:30:00+00:00
# 74166  6869189       13      279.0      304.0 2017-10-27 13:25:00+00:00
# 74167  6869191     8371    10642.0    10729.0 2017-10-27 14:45:00+00:00
#
#                      arrival_ts  price_in_cents  \
# 0     2017-10-13 20:10:00+00:00            4550
# ...
